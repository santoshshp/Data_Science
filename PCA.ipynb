# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib

# %%
# !pip install scikit-learn

# %% [markdown]
# **1. EDA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0             0.28             2.29   5.64  1.04      3.92     1065
# 1             0.26             1.28   4.38  1.05      3.40     1050
# 2             0.30             2.81   5.68  1.03      3.17     1185
# 3             0.24             2.18   7.80  0.86      3.45     1480
# 4             0.39             1.82   4.32  1.04      2.93      735
# ..             ...              ...    ...   ...       ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740
# 174           0.43             1.41   7.30  0.70      1.56      750
# 175           0.43             1.35  10.20  0.59      1.56      835
# 176           0.53             1.46   9.30  0.60      1.62      840
# 177           0.56             1.35   9.20  0.61      1.60      560
#
# [178 rows x 14 columns]

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# std      0.625851    0.998859       0.124453         0.572359    2.318286
# min      0.980000    0.340000       0.130000         0.410000    1.280000
# 25%      1.742500    1.205000       0.270000         1.250000    3.220000
# 50%      2.355000    2.135000       0.340000         1.555000    4.690000
# 75%      2.800000    2.875000       0.437500         1.950000    6.200000
# max      3.880000    5.080000       0.660000         3.580000   13.000000
#
#               Hue    Dilution      Proline
# count  178.000000  178.000000   178.000000
# mean     0.957449    2.611685   746.893258
# std      0.228572    0.709990   314.907474
# min      0.480000    1.270000   278.000000
# 25%      0.782500    1.937500   500.500000
# 50%      0.965000    2.780000   673.500000
# 75%      1.120000    3.170000   985.000000
# max      1.710000    4.000000  1680.000000

# %%
df.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# Length: 178, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.hist(bins=20, figsize=(20,15), color='skyblue', edgecolor='black')
plt.suptitle('Feature Distributions')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# **2. Dimensionality Reduction with PCA**

# %%
from sklearn.preprocessing import StandardScaler

x = df.drop('Alcohol', axis=1)
y = df['Alcohol']

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.decomposition import PCA

pca = PCA()
x_pca = pca.fit_transform(x_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

plt.figure(figsize=(10,6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', label='Individual Variance')
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='s', label='Cumulative Variance', color='orange')
plt.axhline(y=0.95, color='red', linestyle='--', label='95% Variance Threshold')
plt.title('Explained Variance by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.legend()
plt.grid()
plt.show()

# %%
pca_optimal = PCA(n_components=9)
pca_transformed = pca_optimal.fit_transform(x_scaled)

# %% [markdown]
# **3. Clustering with Original Data**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

kmeans = KMeans(n_clusters=3, random_state=42)
clusters_original = kmeans.fit_predict(x_scaled)

silhouette = silhouette_score(x_scaled, clusters_original)
print(f'Silhouette Score (Original Data): {silhouette}')
# Out:
# Silhouette Score (Original Data): 0.28628258889905817

# %%
plt.scatter(x_scaled[:, 0], x_scaled[:, 1], c=clusters_original, cmap='viridis', s=50)
plt.title('K-Means Clustering (Original Data)')
plt.show()

# %% [markdown]
# **4. Clustering with PCA Data**

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
clusters_pca = kmeans.fit_predict(pca_transformed)

silhouette_pca = silhouette_score(pca_transformed, clusters_pca)
print(f'Silhouette Score (PCA Data): {silhouette_pca}')
# Out:
# Silhouette Score (PCA Data): 0.3041443381836876

# %%
plt.scatter(pca_transformed[:, 0], pca_transformed[:, 1], c=clusters_pca, cmap='viridis', s=50)
plt.title('K-Means Clustering (PCA Data)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **5. Comparison and Analysis**

# %%
print(f"Silhouette Score Comparison:")
print(f"Original Data: {silhouette}")
print(f"PCA Data: {silhouette_pca}")
# Out:
# Silhouette Score Comparison:
# Original Data: 0.28628258889905817
# PCA Data: 0.3041443381836876

# %% [markdown]
# # Conclusion and Insights
#
# ### **Key Insights:**
# - The dataset was preprocessed to remove duplicates and handle missing values.
# - PCA analysis showed that a reduced number of components could retain most of the variance, making dimensionality reduction effective.
# - The correlation heatmap revealed relationships between key features, helping in feature selection.
# - Clustering might provide meaningful groupings within the dataset, helping in classification or segmentation tasks.
#
# ### **Conclusion:**
# This analysis provided valuable insights into the dataset by exploring its structure, reducing dimensions with PCA, and performing clustering. The results suggest that dimensionality reduction improves interpretability while retaining significant information. Future work could include refining the clustering model and applying classification techniques for further insights.
